# %%
from graph.workflow import build_graph
from IPython.display import Image, display

graph = build_graph()
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
state_obj.flags["last_event"] = event
new_state = await graph.ainvoke(state_obj)




# simula um evento
state = ProcessState(fase_atual="INTAKE_DOCS", documentos={"fatura": {}})
state.flags["last_event"] = {"type": "upload_doc", "data": {"tipo": "fatura"}}
result = graph.invoke(state)
print(result.fase_atual)  # deve manter INTAKE_DOCS
